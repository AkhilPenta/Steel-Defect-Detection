# %% [markdown]
# ## 7. UNet with Resnet

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from tqdm import tqdm

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Dropout, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.layers import Concatenate, Add
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

# %% [markdown]
# ### 7.1 Loading Data

# %%
path = '/content/drive/MyDrive/cs2/'

# %%
#loading train and validation data
train_data = pd.read_csv(path + "data/train_data.csv").fillna('')
validtn_data = pd.read_csv(path + "data/validtn_data.csv").fillna('')

# %% [markdown]
# ### 7.2 Data Generator Implementation

# %%
# Implementing custom data generator
#https://towardsdatascience.com/implementing-custom-data-generators-in-keras-de56f013581c
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size=32, num_classes=None, shuffle=True, preprocess=None):
        self.batch_size = batch_size
        self.df = dataframe
        self.indices = self.df.index.tolist()
        self.preprocess = preprocess
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return len(self.indices) // (self.batch_size)

    def __getitem__(self, index):
        index = self.index[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def __get_data(self, batch):
        train_datagen = ImageDataGenerator()
        param = {'flip_horizontal':True, 'samplewise_std_normalization' : True,
                 'width_shift_range':0.1, 'height_shift_range':0.1,}
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
        Y = np.empty((self.batch_size,256,1600,4),dtype=np.float32)# 4 masks place-holders
              
        for i, id in enumerate(batch):
          img = Image.open(path+'data/train_images/' + str(self.df['ImageId'].loc[id]))
          X[i,] = train_datagen.apply_transform(x = img, transform_parameters = param)#input image
          for j in range(4): #looping for each class
                mask = rle2mask(self.df['rle_'+str(j+1)].loc[id])
                Y[i,:,:,j] = train_datagen.apply_transform(x = mask, transform_parameters = param)#mask for each class
                
        # preprocess input
        if self.preprocess!=None: X = self.preprocess(X)

        return X, Y

# %% [markdown]
# ### 7.3 Utility Functions

# %%
#https://www.kaggle.com/titericz/building-and-visualizing-masks
#https://www.kaggle.com/paulorzp/rle-functions-run-lenght-encode-decode

#defining function for converting EncodedPixels(rle: run length encoding) to mask
def rle2mask(rle_string, img_shape=(256,1600)):
    '''
    input: EncodedPixels (run-length-encoded) string & image shape:-(width,height)
    output: mask in numpy.ndarray format with shape (256,1600)
    '''
    rle_array = np.array([int(s)for s in rle_string.split()])
    starts_array = rle_array[::2]-1
    lengths_array = rle_array[1::2]
    mask_array = np.zeros(img_shape[0]*img_shape[1],dtype=np.uint8)
    #print(starts_array,lengths_array)
    for i in range(len(starts_array)):
        mask_array[starts_array[i]:starts_array[i]+lengths_array[i]] = 1
    #order='F' because encoded pixels are numbered from top to bottom, then left to right
    return mask_array.reshape(img_shape, order = 'F')

#defining function for converting given mask to EncodedPixels(rle: run length encoding)
def mask2rle(mask_array):
    '''
    input: mask in numpy.ndarray format
    output: EncodedPixels (run-length-encoded) string
    '''
    mask_array = mask_array.T.flatten()
    mask_array = np.concatenate([[0], mask_array, [0]])
    rle_array = np.where(mask_array[1:]!=mask_array[:-1])[0]+1
    rle_array[1::2] -= rle_array[::2]
    rle_string = ' '.join(map(str,rle_array))
    return rle_string

#defining function for calculation of metric dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.math.reduce_sum(y_true_f * y_pred_f)
    smoothing_const = 1e-9
    return (2. * intersection + smoothing_const) / (tf.math.reduce_sum(y_true_f) + tf.math.reduce_sum(y_pred_f) + smoothing_const)

#defining function for calculation of dice coefficient
def dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return (1-dice_coefficient(y_true, y_pred))

#defining function for calculation of loss function: binary cross entropy + dice loss
def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return binary_crossentropy(y_true, y_pred) + (1-dice_coefficient(y_true, y_pred))

# %% [markdown]
# ### 7.4 Defining Unet Architecture with ResNet as backbone

# %%
# defining Unet architecture with Resnet as backbone
# https://medium.com/@nishanksingla/unet-with-resblock-for-semantic-segmentation-dd1766b4ff66
# https://github.com/Nishanksingla/UNet-with-ResBlock/blob/master/resnet34_unet_model.py
# https://towardsdatascience.com/understanding-semantic-segmentation-with-unet-6be4f42d4b47
# https://github.com/hlamba28/UNET-TGS

def ResBlock(input_tensor, n_filters, kernel_size = 3, batchnorm = True ):
    """function to pass Input_tensor through Resnet block configured as per the input parameters"""

    # Residual/Skip connection
    res = Conv2D(filters = n_filters, kernel_size=(1,1),\
               kernel_initializer = 'he_normal', padding='same')(input_tensor)

    # first Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    # second Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)

    resconnection = Add()([res, x])
    x = Activation('relu')(resconnection)

    return x

def Unet_withResnet_Model(input_image, n_filters = 16, batchnorm = True):
    # Encoder (Contraction Path)
    E1 = ResBlock(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(E1)
    #p1 = Dropout(dropout)(p1)

    E2 = ResBlock(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(E2)
    #p2 = Dropout(dropout)(p2)

    E3 = ResBlock(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(E3)
    #p3 = Dropout(dropout)(p3)

    E4 = ResBlock(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(E4)
    #p4 = Dropout(dropout)(p4)

    E5 = ResBlock(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

    # Decoder (Expansive Path)
    D6 = Conv2DTranspose(n_filters * 8, kernel_size = (3, 3), strides = (2, 2), padding = 'same')(E5)
    D6 = Concatenate()([D6, E4])
    #D6 = Dropout(dropout)(D6)
    E6 = ResBlock(D6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

    D7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(E6)
    D7 = Concatenate()([D7, E3])
    #D7 = Dropout(dropout)(D7)
    E7 = ResBlock(D7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

    D8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(E7)
    D8 = Concatenate()([D8, E2])
    #D8 = Dropout(dropout)(D8)
    E8 = ResBlock(D8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

    D9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(E8)
    D9 = Concatenate()([D9, E1])
    #D9 = Dropout(dropout)(D9)
    E9 = ResBlock(D9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

    outputs = Conv2D(4, (1, 1), activation='sigmoid')(E9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
#configuring input tensor
input_img = Input((256, 1600, 3), name='img')

model = Unet_withResnet_Model(input_img, n_filters=8, batchnorm=True)
model.compile(optimizer=Adam(), loss=bce_dice_loss, metrics=[dice_coefficient])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 1600, 3 0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 1600, 8) 224         img[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 1600, 8) 32          img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 1600, 8) 32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 1600, 8) 0           conv2d[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 1600, 8) 0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 800, 8)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 800, 16) 1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 800, 16) 144         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 800, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 800, 16) 0           conv2d_3[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 800, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 400, 16)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 400, 32)  4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 400, 32)  544         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 400, 32)  128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 400, 32)  0           conv2d_6[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 400, 32)  0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 200, 32)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 200, 64)  18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 200, 64)  2112        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 200, 64)  256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 200, 64)  0           conv2d_9[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 200, 64)  0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 100, 64)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 100, 128) 73856       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 100, 128) 8320        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 100, 128) 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 100, 128) 0           conv2d_12[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 100, 128) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 200, 64)  73792       activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 200, 128) 0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 200, 64)  73792       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 200, 64)  8256        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 200, 64)  256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 200, 64)  0           conv2d_15[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 200, 64)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 400, 32)  18464       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 400, 64)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 400, 32)  18464       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 400, 32)  2080        concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 400, 32)  128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 400, 32)  0           conv2d_18[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 400, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 800, 16) 4624        activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 800, 32) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 800, 16) 4624        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 800, 16) 528         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 800, 16) 64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 128, 800, 16) 0           conv2d_21[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 800, 16) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 1600, 8) 1160        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 1600, 16 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 1600, 8) 1160        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 1600, 8) 136         concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 1600, 8) 32          conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 256, 1600, 8) 0           conv2d_24[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 1600, 8) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 1600, 4) 36          activation_17[0][0]
# ==================================================================================================
# Total params: 318,124
# Trainable params: 317,388
# Non-trainable params: 736
# __________________________________________________________________________________________________

# %%
#loading train & validation data using DataGenerator class defined
train_batches = DataGenerator(train_data,shuffle=True)
validtn_batches = DataGenerator(validtn_data,shuffle=False)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import datetime, os

# #tensorboard for visualizing loss & metric summary 
# logdir = path+"logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(logdir)

#defining ModelCheckpoint to make a checkpoint when validation dice coefficient improves
checkpoints = ModelCheckpoint(path+'Unet_withResnet.h5', \
                              monitor='val_dice_coefficient', verbose=1, save_best_only=True, mode='max')

#adding ModelCheckpoint & TensorBoard to callback functions list
callbacks_list = [checkpoints]

# %% [markdown]
# ### 7.5 Traing Model

# %%
# fit model
history = model.fit(train_batches,validation_data=validtn_batches, epochs = 60, callbacks=callbacks_list)
# Out:
# Epoch 1/60
# 333/333 [==============================] - 3367s 10s/step - loss: 2.3249 - dice_coefficient: 0.0199 - val_loss: 1.0448 - val_dice_coefficient: 0.0231
#
# Epoch 00001: val_dice_coefficient improved from -inf to 0.02311, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 2/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.9736 - dice_coefficient: 0.0743 - val_loss: 0.9833 - val_dice_coefficient: 0.0992
#
# Epoch 00002: val_dice_coefficient improved from 0.02311 to 0.09919, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 3/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.8817 - dice_coefficient: 0.1846 - val_loss: 1.0425 - val_dice_coefficient: 0.0409
#
# Epoch 00003: val_dice_coefficient did not improve from 0.09919
# Epoch 4/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.8160 - dice_coefficient: 0.2429 - val_loss: 0.9893 - val_dice_coefficient: 0.0896
#
# Epoch 00004: val_dice_coefficient did not improve from 0.09919
# Epoch 5/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.7822 - dice_coefficient: 0.2732 - val_loss: 0.8405 - val_dice_coefficient: 0.2292
#
# Epoch 00005: val_dice_coefficient improved from 0.09919 to 0.22925, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 6/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.7087 - dice_coefficient: 0.3440 - val_loss: 0.7333 - val_dice_coefficient: 0.3246
#
# Epoch 00006: val_dice_coefficient improved from 0.22925 to 0.32458, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 7/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.6478 - dice_coefficient: 0.4009 - val_loss: 0.8480 - val_dice_coefficient: 0.2209
#
# Epoch 00007: val_dice_coefficient did not improve from 0.32458
# Epoch 8/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.6183 - dice_coefficient: 0.4276 - val_loss: 0.8466 - val_dice_coefficient: 0.2167
#
# Epoch 00008: val_dice_coefficient did not improve from 0.32458
# Epoch 9/60
# 333/333 [==============================] - 411s 1s/step - loss: 0.5872 - dice_coefficient: 0.4577 - val_loss: 0.6951 - val_dice_coefficient: 0.3716
#
# Epoch 00009: val_dice_coefficient improved from 0.32458 to 0.37163, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 10/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5768 - dice_coefficient: 0.4663 - val_loss: 0.7981 - val_dice_coefficient: 0.2751
#
# Epoch 00010: val_dice_coefficient did not improve from 0.37163
# Epoch 11/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5751 - dice_coefficient: 0.4685 - val_loss: 0.9055 - val_dice_coefficient: 0.2234
#
# Epoch 00011: val_dice_coefficient did not improve from 0.37163
# Epoch 12/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.5688 - dice_coefficient: 0.4737 - val_loss: 0.5791 - val_dice_coefficient: 0.4695
#
# Epoch 00012: val_dice_coefficient improved from 0.37163 to 0.46947, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 13/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5499 - dice_coefficient: 0.4910 - val_loss: 0.6312 - val_dice_coefficient: 0.4225
#
# Epoch 00013: val_dice_coefficient did not improve from 0.46947
# Epoch 14/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5512 - dice_coefficient: 0.4900 - val_loss: 0.6099 - val_dice_coefficient: 0.4382
#
# Epoch 00014: val_dice_coefficient did not improve from 0.46947
# Epoch 15/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5500 - dice_coefficient: 0.4892 - val_loss: 0.5447 - val_dice_coefficient: 0.5006
#
# Epoch 00015: val_dice_coefficient improved from 0.46947 to 0.50056, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 16/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.5254 - dice_coefficient: 0.5137 - val_loss: 0.5776 - val_dice_coefficient: 0.4738
#
# Epoch 00016: val_dice_coefficient did not improve from 0.50056
# Epoch 17/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5351 - dice_coefficient: 0.5058 - val_loss: 0.6032 - val_dice_coefficient: 0.4487
#
# Epoch 00017: val_dice_coefficient did not improve from 0.50056
# Epoch 18/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5122 - dice_coefficient: 0.5255 - val_loss: 0.5960 - val_dice_coefficient: 0.4619
#
# Epoch 00018: val_dice_coefficient did not improve from 0.50056
# Epoch 19/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5124 - dice_coefficient: 0.5259 - val_loss: 0.5830 - val_dice_coefficient: 0.4732
#
# Epoch 00019: val_dice_coefficient did not improve from 0.50056
# Epoch 20/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5048 - dice_coefficient: 0.5318 - val_loss: 0.5413 - val_dice_coefficient: 0.4949
#
# Epoch 00020: val_dice_coefficient did not improve from 0.50056
# Epoch 21/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4984 - dice_coefficient: 0.5381 - val_loss: 0.6957 - val_dice_coefficient: 0.3805
#
# Epoch 00021: val_dice_coefficient did not improve from 0.50056
# Epoch 22/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.5112 - dice_coefficient: 0.5261 - val_loss: 1.9946 - val_dice_coefficient: 0.0679
#
# Epoch 00022: val_dice_coefficient did not improve from 0.50056
# Epoch 23/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4977 - dice_coefficient: 0.5388 - val_loss: 0.6273 - val_dice_coefficient: 0.4171
#
# Epoch 00023: val_dice_coefficient did not improve from 0.50056
# Epoch 24/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4868 - dice_coefficient: 0.5491 - val_loss: 0.5355 - val_dice_coefficient: 0.5046
#
# Epoch 00024: val_dice_coefficient improved from 0.50056 to 0.50458, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 25/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4920 - dice_coefficient: 0.5440 - val_loss: 0.5329 - val_dice_coefficient: 0.5148
#
# Epoch 00025: val_dice_coefficient improved from 0.50458 to 0.51484, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 26/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4795 - dice_coefficient: 0.5563 - val_loss: 0.7921 - val_dice_coefficient: 0.3021
#
# Epoch 00026: val_dice_coefficient did not improve from 0.51484
# Epoch 27/60
# 333/333 [==============================] - 411s 1s/step - loss: 0.4895 - dice_coefficient: 0.5461 - val_loss: 0.7567 - val_dice_coefficient: 0.3124
#
# Epoch 00027: val_dice_coefficient did not improve from 0.51484
# Epoch 28/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4778 - dice_coefficient: 0.5574 - val_loss: 0.5770 - val_dice_coefficient: 0.4724
#
# Epoch 00028: val_dice_coefficient did not improve from 0.51484
# Epoch 29/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4670 - dice_coefficient: 0.5676 - val_loss: 0.5920 - val_dice_coefficient: 0.4630
#
# Epoch 00029: val_dice_coefficient did not improve from 0.51484
# Epoch 30/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.4684 - dice_coefficient: 0.5664 - val_loss: 0.5219 - val_dice_coefficient: 0.5234
#
# Epoch 00030: val_dice_coefficient improved from 0.51484 to 0.52344, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 31/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4611 - dice_coefficient: 0.5723 - val_loss: 0.6329 - val_dice_coefficient: 0.4183
#
# Epoch 00031: val_dice_coefficient did not improve from 0.52344
# Epoch 32/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4511 - dice_coefficient: 0.5825 - val_loss: 0.5215 - val_dice_coefficient: 0.5220
#
# Epoch 00032: val_dice_coefficient did not improve from 0.52344
# Epoch 33/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4445 - dice_coefficient: 0.5881 - val_loss: 0.5182 - val_dice_coefficient: 0.5256
#
# Epoch 00033: val_dice_coefficient improved from 0.52344 to 0.52560, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 34/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4361 - dice_coefficient: 0.5968 - val_loss: 0.5954 - val_dice_coefficient: 0.4557
#
# Epoch 00034: val_dice_coefficient did not improve from 0.52560
# Epoch 35/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4442 - dice_coefficient: 0.5887 - val_loss: 0.5552 - val_dice_coefficient: 0.4975
#
# Epoch 00035: val_dice_coefficient did not improve from 0.52560
# Epoch 36/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4308 - dice_coefficient: 0.6015 - val_loss: 1.1314 - val_dice_coefficient: 0.1103
#
# Epoch 00036: val_dice_coefficient did not improve from 0.52560
# Epoch 37/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4294 - dice_coefficient: 0.6017 - val_loss: 0.4632 - val_dice_coefficient: 0.5749
#
# Epoch 00037: val_dice_coefficient improved from 0.52560 to 0.57489, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 38/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.4249 - dice_coefficient: 0.6069 - val_loss: 0.5474 - val_dice_coefficient: 0.4992
#
# Epoch 00038: val_dice_coefficient did not improve from 0.57489
# Epoch 39/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4244 - dice_coefficient: 0.6072 - val_loss: 0.8873 - val_dice_coefficient: 0.2141
#
# Epoch 00039: val_dice_coefficient did not improve from 0.57489
# Epoch 40/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4150 - dice_coefficient: 0.6166 - val_loss: 2.4748 - val_dice_coefficient: 0.0596
#
# Epoch 00040: val_dice_coefficient did not improve from 0.57489
# Epoch 41/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.4109 - dice_coefficient: 0.6200 - val_loss: 0.5521 - val_dice_coefficient: 0.4938
#
# Epoch 00041: val_dice_coefficient did not improve from 0.57489
# Epoch 42/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4088 - dice_coefficient: 0.6220 - val_loss: 0.6848 - val_dice_coefficient: 0.3828
#
# Epoch 00042: val_dice_coefficient did not improve from 0.57489
# Epoch 43/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.4132 - dice_coefficient: 0.6165 - val_loss: 0.6030 - val_dice_coefficient: 0.4550
#
# Epoch 00043: val_dice_coefficient did not improve from 0.57489
# Epoch 44/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.4101 - dice_coefficient: 0.6203 - val_loss: 0.5189 - val_dice_coefficient: 0.5251
#
# Epoch 00044: val_dice_coefficient did not improve from 0.57489
# Epoch 45/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.3961 - dice_coefficient: 0.6347 - val_loss: 0.6109 - val_dice_coefficient: 0.4494
#
# Epoch 00045: val_dice_coefficient did not improve from 0.57489
# Epoch 46/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4008 - dice_coefficient: 0.6295 - val_loss: 0.5198 - val_dice_coefficient: 0.5271
#
# Epoch 00046: val_dice_coefficient did not improve from 0.57489
# Epoch 47/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.3978 - dice_coefficient: 0.6319 - val_loss: 0.7719 - val_dice_coefficient: 0.3202
#
# Epoch 00047: val_dice_coefficient did not improve from 0.57489
# Epoch 48/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.4052 - dice_coefficient: 0.6240 - val_loss: 0.5250 - val_dice_coefficient: 0.5204
#
# Epoch 00048: val_dice_coefficient did not improve from 0.57489
# Epoch 49/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3951 - dice_coefficient: 0.6339 - val_loss: 0.5326 - val_dice_coefficient: 0.5144
#
# Epoch 00049: val_dice_coefficient did not improve from 0.57489
# Epoch 50/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3805 - dice_coefficient: 0.6480 - val_loss: 0.4415 - val_dice_coefficient: 0.5935
#
# Epoch 00050: val_dice_coefficient improved from 0.57489 to 0.59348, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 51/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.3874 - dice_coefficient: 0.6421 - val_loss: 0.5423 - val_dice_coefficient: 0.5028
#
# Epoch 00051: val_dice_coefficient did not improve from 0.59348
# Epoch 52/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3829 - dice_coefficient: 0.6452 - val_loss: 1.9222 - val_dice_coefficient: 0.0618
#
# Epoch 00052: val_dice_coefficient did not improve from 0.59348
# Epoch 53/60
# 333/333 [==============================] - 409s 1s/step - loss: 0.3801 - dice_coefficient: 0.6481 - val_loss: 0.6150 - val_dice_coefficient: 0.4440
#
# Epoch 00053: val_dice_coefficient did not improve from 0.59348
# Epoch 54/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3794 - dice_coefficient: 0.6496 - val_loss: 0.5149 - val_dice_coefficient: 0.5294
#
# Epoch 00054: val_dice_coefficient did not improve from 0.59348
# Epoch 55/60
# 333/333 [==============================] - 411s 1s/step - loss: 0.3740 - dice_coefficient: 0.6540 - val_loss: 0.4635 - val_dice_coefficient: 0.5756
#
# Epoch 00055: val_dice_coefficient did not improve from 0.59348
# Epoch 56/60
# 333/333 [==============================] - 411s 1s/step - loss: 0.3671 - dice_coefficient: 0.6606 - val_loss: 0.4330 - val_dice_coefficient: 0.6018
#
# Epoch 00056: val_dice_coefficient improved from 0.59348 to 0.60182, saving model to /content/drive/MyDrive/cs2/Unet_withResnet.h5
# Epoch 57/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3625 - dice_coefficient: 0.6649 - val_loss: 0.4941 - val_dice_coefficient: 0.5527
#
# Epoch 00057: val_dice_coefficient did not improve from 0.60182
# Epoch 58/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3663 - dice_coefficient: 0.6606 - val_loss: 0.4917 - val_dice_coefficient: 0.5509
#
# Epoch 00058: val_dice_coefficient did not improve from 0.60182
# Epoch 59/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3570 - dice_coefficient: 0.6694 - val_loss: 0.5999 - val_dice_coefficient: 0.4514
#
# Epoch 00059: val_dice_coefficient did not improve from 0.60182
# Epoch 60/60
# 333/333 [==============================] - 410s 1s/step - loss: 0.3558 - dice_coefficient: 0.6709 - val_loss: 0.4933 - val_dice_coefficient: 0.5473
#
# Epoch 00060: val_dice_coefficient did not improve from 0.60182

# %%
# Visualizing history for dice_coefficient
plt.figure(figsize=(12, 8))
plt.plot(history.history['dice_coefficient'])
plt.plot(history.history['val_dice_coefficient'])
plt.title('model dice_coefficient')
plt.ylabel('dice_coefficient')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()
# Visualizing history for loss
plt.figure(figsize=(12, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('bce_dice_loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()

# %%
# saving history data for first 60 epochs in csv file
history1 = pd.DataFrame(history.history)
history1.to_csv(path + "data/history1-Unet_withResnet.csv", index=True)
# saving model(weights upto 60 epochs)
model.save(path+'Unet_withResnet-60epochs.h5')

# %% [markdown]
# ### 7.6 Visualizing Model Predictions

# %%
# evaluating model(best weights) with the validation batch
model.load_weights(path + 'Unet_withResnet.h5')
loss, dc= model.evaluate(validtn_batches,verbose=1)
print('loss:',loss, 'dice_coefficient:',dc)
# Out:
# 58/58 [==============================] - 40s 689ms/step - loss: 0.4330 - dice_coefficient: 0.6018
# loss: 0.4329618215560913 dice_coefficient: 0.6018213033676147

# %%
#defining function to display GroundTruth & Predicted mask images for a given imageId
def visualize_model_prediction(img_id):
    fig, axs = plt.subplots(4, 3, figsize=(16,8))
    img_obj = cv2.imread(path+'data/train_images/'+ img_id)
    masks_actual = full_data[full_data['ImageId'] == img_id]
    x = np.empty((1,256,1600,3),dtype=np.float32) # image place-holders
    x[0,] = Image.open(path+'data/train_images/' + img_id)
    masks_predicted = model.predict(x)
    for i in range(4):
        axs[i,0].imshow(img_obj)
        axs[i,0].set_title(img_id)
        axs[i,1].imshow(rle2mask(masks_actual['rle_'+str(i+1)].iloc[0]))
        axs[i,1].set_title("Actual mask for Class '{}'".format(i+1) )
        axs[i,2].imshow(masks_predicted[0,:,:,i])
        axs[i,2].set_title("Predicted mask for Class '{}'".format(i+1))
    plt.show()

# %%
visualize_model_prediction('0002cc93b.jpg')

# %%
visualize_model_prediction('4d38c353e.jpg')

# %% [markdown]
# ### 7.7 Preparing Data for submission

# %%
class PredictDataGenerator(tf.keras.utils.Sequence):
    def __init__(self,dataframe, list_idcs, batch_size=32, ):
        self.batch_size = batch_size
        self.df = dataframe
        self.list_idcs = list_idcs
        self.indices = self.df.index.tolist()
        self.rem = len(self.list_idcs) % (self.batch_size)
        self.on_epoch_end()

    def __len__(self):
         return len(self.list_idcs) // (self.batch_size)
#         if (self.rem) == 0:
#             return len(self.list_idcs) // (self.batch_size)
#         else:
#             return (len(self.list_idcs) // (self.batch_size) )+1

    def __getitem__(self, index):
        index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         if ((index + 1) * self.batch_size) < len(self.list_idcs):
#             index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         else:
#             index = self.indices[index * self.batch_size: (index * self.batch_size)+ self.rem]
        batch = [self.list_idcs[k] for k in index]
        
        X = self.__get_data(batch)
         
        return X
    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))

    def __get_data(self, batch):
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
              
        for i, id in enumerate(batch):
            img = Image.open(path + 'data/test_images/' + str(self.df['ImageId'].loc[id]))
            X[i,] = img#input image

        return X

# %%
test_img_IDs = list(os.listdir(path + 'data/test_images/'))
test_imgsIds_df = pd.DataFrame({'ImageId': test_img_IDs})
print(len(test_imgsIds_df))
test_imgsIds_df.head()
# Out:
# 5506
#          ImageId
# 0  d3dcedbd7.jpg
# 1  db7cff638.jpg
# 2  d3764cee5.jpg
# 3  d387d301f.jpg
# 4  d221d2a3f.jpg

# %%
SubmissionDf = pd.DataFrame(columns = ['ImageId','EncodedPixels','ClassId'])

# %%
for i in range(0,len(test_imgsIds_df),320):
    batch_idcs =  list(range(i, min(test_imgsIds_df.shape[0], i + 320)))#.iloc[batch_idcs]
    if len(batch_idcs)== 320:        
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs)
    else:
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs,
                                             batch_size= len(batch_idcs))
    #print(len(test_subbatch))
    subbatch_pred_masks = model.predict(test_subbatch)
    #print(len(subbatch_pred_masks))
    #break
    for j, idx in tqdm(enumerate(batch_idcs)):
        filename = test_imgsIds_df['ImageId'].iloc[idx]
        rle1 = mask2rle(subbatch_pred_masks[j,:,:,0].round().astype(int))
        rle2 = mask2rle(subbatch_pred_masks[j,:,:,1].round().astype(int))
        rle3 = mask2rle(subbatch_pred_masks[j,:,:,2].round().astype(int))
        rle4 = mask2rle(subbatch_pred_masks[j,:,:,3].round().astype(int))
        df = pd.DataFrame({'ImageId':[filename]*4,
                      'EncodedPixels': [rle1,rle2,rle3,rle4],
                      'ClassId':['1', '2', '3', '4']})
        SubmissionDf = SubmissionDf.append(df,ignore_index=True)
# Out:
# 320it [00:03, 81.17it/s]
# 320it [00:03, 80.86it/s]
# 320it [00:04, 78.28it/s]
# 320it [00:04, 78.80it/s]
# 320it [00:03, 80.57it/s]
# 320it [00:04, 79.70it/s]
# 320it [00:03, 81.11it/s]
# 320it [00:03, 80.45it/s]
# 320it [00:04, 79.37it/s]
# 320it [00:04, 77.46it/s]
# 320it [00:04, 79.03it/s]
# 320it [00:04, 78.34it/s]
# 320it [00:04, 76.99it/s]
# 320it [00:04, 77.08it/s]
# 320it [00:04, 77.48it/s]
# 320it [00:04, 77.93it/s]
# 320it [00:04, 77.75it/s]
# 66it [00:00, 79.21it/s]

# %%
SubmissionDf.sort_values(by=['ImageId', 'ClassId'], inplace=True)
SubmissionDf['ImageId_ClassId'] = SubmissionDf['ImageId'] + '_' + SubmissionDf['ClassId']
print(SubmissionDf.shape)
SubmissionDf.head(10)
# Out:
# (22024, 4)
#              ImageId  ...  ImageId_ClassId
# 20016  0000f269f.jpg  ...  0000f269f.jpg_1
# 20017  0000f269f.jpg  ...  0000f269f.jpg_2
# 20018  0000f269f.jpg  ...  0000f269f.jpg_3
# 20019  0000f269f.jpg  ...  0000f269f.jpg_4
# 20004  000ccc2ac.jpg  ...  000ccc2ac.jpg_1
# 20005  000ccc2ac.jpg  ...  000ccc2ac.jpg_2
# 20006  000ccc2ac.jpg  ...  000ccc2ac.jpg_3
# 20007  000ccc2ac.jpg  ...  000ccc2ac.jpg_4
# 20012  002451917.jpg  ...  002451917.jpg_1
# 20013  002451917.jpg  ...  002451917.jpg_2
#
# [10 rows x 4 columns]

# %%
SubmissionDf.to_csv(path+'submission-Unet_withResnet.csv', index=False)

# %%
# dot_img_file = '/tmp/model.png'
# tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %% [markdown]
# ### 7.8 Kaggle Submission Score

# %%
#Kaggle Score
from IPython.display import Image
Image(filename='unet with resnet.JPG')
