# %% [markdown]
# ## 8. LinkNet with Resnet

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from tqdm import tqdm

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Dropout, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.layers import Concatenate, Add
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

# %% [markdown]
# ### 8.1 Loading Data

# %%
path = '/content/drive/MyDrive/cs2/'

# %%
#loading train and validation data
train_data = pd.read_csv(path + "data/train_data.csv").fillna('')
validtn_data = pd.read_csv(path + "data/validtn_data.csv").fillna('')

# %% [markdown]
# ### 8.2 Data Generator Implementation

# %%
# Implementing custom data generator
#https://towardsdatascience.com/implementing-custom-data-generators-in-keras-de56f013581c
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size=32, num_classes=None, shuffle=True, preprocess=None):
        self.batch_size = batch_size
        self.df = dataframe
        self.indices = self.df.index.tolist()
        self.preprocess = preprocess
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return len(self.indices) // (self.batch_size)

    def __getitem__(self, index):
        index = self.index[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def __get_data(self, batch):
        train_datagen = ImageDataGenerator()
        param = {'flip_horizontal':True, 'samplewise_std_normalization' : True,
                 'width_shift_range':0.1, 'height_shift_range':0.1,}
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
        Y = np.empty((self.batch_size,256,1600,4),dtype=np.float32)# 4 masks place-holders
              
        for i, id in enumerate(batch):
          img = Image.open(path+'data/train_images/' + str(self.df['ImageId'].loc[id]))
          X[i,] = train_datagen.apply_transform(x = img, transform_parameters = param)#input image
          for j in range(4): #looping for each class
                mask = rle2mask(self.df['rle_'+str(j+1)].loc[id])
                Y[i,:,:,j] = train_datagen.apply_transform(x = mask, transform_parameters = param)#mask for each class
                
        # preprocess input
        if self.preprocess!=None: X = self.preprocess(X)

        return X, Y

# %% [markdown]
# ### 8.3 Utility Functions

# %%
#https://www.kaggle.com/titericz/building-and-visualizing-masks
#https://www.kaggle.com/paulorzp/rle-functions-run-lenght-encode-decode

#defining function for converting EncodedPixels(rle: run length encoding) to mask
def rle2mask(rle_string, img_shape=(256,1600)):
    '''
    input: EncodedPixels (run-length-encoded) string & image shape:-(width,height)
    output: mask in numpy.ndarray format with shape (256,1600)
    '''
    rle_array = np.array([int(s)for s in rle_string.split()])
    starts_array = rle_array[::2]-1
    lengths_array = rle_array[1::2]
    mask_array = np.zeros(img_shape[0]*img_shape[1],dtype=np.uint8)
    #print(starts_array,lengths_array)
    for i in range(len(starts_array)):
        mask_array[starts_array[i]:starts_array[i]+lengths_array[i]] = 1
    #order='F' because encoded pixels are numbered from top to bottom, then left to right
    return mask_array.reshape(img_shape, order = 'F')

#defining function for converting given mask to EncodedPixels(rle: run length encoding)
def mask2rle(mask_array):
    '''
    input: mask in numpy.ndarray format
    output: EncodedPixels (run-length-encoded) string
    '''
    mask_array = mask_array.T.flatten()
    mask_array = np.concatenate([[0], mask_array, [0]])
    rle_array = np.where(mask_array[1:]!=mask_array[:-1])[0]+1
    rle_array[1::2] -= rle_array[::2]
    rle_string = ' '.join(map(str,rle_array))
    return rle_string

#defining function for calculation of metric dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.math.reduce_sum(y_true_f * y_pred_f)
    smoothing_const = 1e-9
    return (2. * intersection + smoothing_const) / (tf.math.reduce_sum(y_true_f) + tf.math.reduce_sum(y_pred_f) + smoothing_const)

#defining function for calculation of dice coefficient
def dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return (1-dice_coefficient(y_true, y_pred))

#defining function for calculation of loss function: binary cross entropy + dice loss
def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return binary_crossentropy(y_true, y_pred) + (1-dice_coefficient(y_true, y_pred))

# %% [markdown]
# ### 8.4 Defining Linknet Architecture with ResNet as backbone

# %%
# defining Linknet architecture with Resnet as backbone
# https://github.com/qubvel/segmentation_models/blob/master/segmentation_models/models/linknet.py
# https://medium.com/@nishanksingla/unet-with-resblock-for-semantic-segmentation-dd1766b4ff66
# https://github.com/Nishanksingla/UNet-with-ResBlock/blob/master/resnet34_unet_model.py
# https://github.com/hlamba28/UNET-TGS

def ResBlock(input_tensor, n_filters, kernel_size = 3, batchnorm = True ):
    """function to pass Input_tensor through Resnet block configured as per the input parameters"""

    # Residual/Skip connection
    res = Conv2D(filters = n_filters, kernel_size=(1,1),\
               kernel_initializer = 'he_normal', padding='same')(input_tensor)

    # first Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    # second Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)

    resconnection = Add()([res, x])
    x = Activation('relu')(resconnection)

    return x


def linknet_withResnet_Model(input_image, n_filters = 16, batchnorm = True):
    # Encoder (Contraction Path)
    E1 = ResBlock(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(E1)
    #p1 = Dropout(dropout)(p1)

    E2 = ResBlock(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(E2)
    #p2 = Dropout(dropout)(p2)

    E3 = ResBlock(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(E3)
    #p3 = Dropout(dropout)(p3)

    E4 = ResBlock(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(E4)
    #p4 = Dropout(dropout)(p4)

    E5 = ResBlock(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

    # Decoder (Expansive Path)
    D6 = Conv2DTranspose(n_filters * 8, kernel_size = (3, 3), strides = (2, 2), padding = 'same')(E5)
    D6 = Add()([D6, E4])
    #D6 = Dropout(dropout)(D6)
    E6 = ResBlock(D6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

    D7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(E6)
    D7 = Add()([D7, E3])
    #D7 = Dropout(dropout)(D7)
    E7 = ResBlock(D7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

    D8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(E7)
    D8 = Add()([D8, E2])
    #D8 = Dropout(dropout)(D8)
    E8 = ResBlock(D8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

    D9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(E8)
    D9 = Add()([D9, E1])
    #D9 = Dropout(dropout)(D9)
    E9 = ResBlock(D9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

    outputs = Conv2D(4, (1, 1), activation='sigmoid')(E9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((256, 1600, 3), name='img')
model = linknet_withResnet_Model(input_img, n_filters=8, batchnorm=True)
model.compile(optimizer=Adam(), loss=bce_dice_loss, metrics=[dice_coefficient])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 1600, 3 0
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 256, 1600, 8) 224         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 1600, 8) 32          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 256, 1600, 8) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 256, 1600, 8) 584         activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 256, 1600, 8) 32          img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256, 1600, 8) 32          conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 256, 1600, 8) 0           conv2d_56[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 256, 1600, 8) 0           add_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 128, 800, 8)  0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 128, 800, 16) 1168        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 800, 16) 64          conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 128, 800, 16) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 128, 800, 16) 2320        activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 128, 800, 16) 144         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 800, 16) 64          conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 128, 800, 16) 0           conv2d_59[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 128, 800, 16) 0           add_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 64, 400, 16)  0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 400, 32)  4640        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 400, 32)  128         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 400, 32)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 400, 32)  9248        activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 400, 32)  544         max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 400, 32)  128         conv2d_64[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 64, 400, 32)  0           conv2d_62[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 400, 32)  0           add_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 32, 200, 32)  0           activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 200, 64)  18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 200, 64)  256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 200, 64)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 200, 64)  36928       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 200, 64)  2112        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 200, 64)  256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 32, 200, 64)  0           conv2d_65[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 200, 64)  0           add_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 16, 100, 64)  0           activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 100, 128) 73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 100, 128) 512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 100, 128) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 100, 128) 147584      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 100, 128) 8320        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 16, 100, 128) 512         conv2d_70[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 16, 100, 128) 0           conv2d_68[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 16, 100, 128) 0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 32, 200, 64)  73792       activation_45[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 200, 64)  0           conv2d_transpose_8[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 200, 64)  36928       add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 32, 200, 64)  256         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 200, 64)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 200, 64)  36928       activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 200, 64)  4160        add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 32, 200, 64)  256         conv2d_73[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 200, 64)  0           conv2d_71[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 200, 64)  0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 64, 400, 32)  18464       activation_47[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 64, 400, 32)  0           conv2d_transpose_9[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 400, 32)  9248        add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64, 400, 32)  128         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 400, 32)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 400, 32)  9248        activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 400, 32)  1056        add_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 400, 32)  128         conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 64, 400, 32)  0           conv2d_74[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 64, 400, 32)  0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 128, 800, 16) 4624        activation_49[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 128, 800, 16) 0           conv2d_transpose_10[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 128, 800, 16) 2320        add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128, 800, 16) 64          conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 800, 16) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 128, 800, 16) 2320        activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 128, 800, 16) 272         add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 128, 800, 16) 64          conv2d_79[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 128, 800, 16) 0           conv2d_77[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 128, 800, 16) 0           add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 256, 1600, 8) 1160        activation_51[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 256, 1600, 8) 0           conv2d_transpose_11[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 256, 1600, 8) 584         add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 256, 1600, 8) 32          conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 256, 1600, 8) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 256, 1600, 8) 584         activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 256, 1600, 8) 72          add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 256, 1600, 8) 32          conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 256, 1600, 8) 0           conv2d_80[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 256, 1600, 8) 0           add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 256, 1600, 4) 36          activation_53[0][0]
# ==================================================================================================
# Total params: 510,940
# Trainable params: 509,468
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
#loading train & validation data using DataGenerator class defined
train_batches = DataGenerator(train_data,shuffle=True)
validtn_batches = DataGenerator(validtn_data,shuffle=False)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import datetime, os

# #tensorboard for visualizing loss & metric summary 
# logdir = path+"logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(logdir)

#defining ModelCheckpoint to make a checkpoint when validation dice coefficient improves
checkpoints = ModelCheckpoint(path+'linknet_withResnet.h5' , monitor='val_dice_coefficient', verbose=1, save_best_only=True, mode='max')

#adding ModelCheckpoint & TensorBoard to callback functions list
callbacks_list = [checkpoints]

# %% [markdown]
# ### 8.5 Traing Model (1-30 epochs)

# %%
# fit model
history = model.fit(train_batches,validation_data=validtn_batches, epochs = 30, callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 333/333 [==============================] - 4648s 14s/step - loss: 5.6820 - dice_coefficient: 0.0148 - val_loss: 1.2927 - val_dice_coefficient: 0.0213
#
# Epoch 00001: val_dice_coefficient improved from -inf to 0.02135, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 2/30
# 333/333 [==============================] - 546s 2s/step - loss: 1.2450 - dice_coefficient: 0.0223 - val_loss: 1.1401 - val_dice_coefficient: 0.0389
#
# Epoch 00002: val_dice_coefficient improved from 0.02135 to 0.03889, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 3/30
# 333/333 [==============================] - 546s 2s/step - loss: 1.1289 - dice_coefficient: 0.0339 - val_loss: 1.1252 - val_dice_coefficient: 0.0598
#
# Epoch 00003: val_dice_coefficient improved from 0.03889 to 0.05978, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 4/30
# 333/333 [==============================] - 545s 2s/step - loss: 1.0191 - dice_coefficient: 0.1059 - val_loss: 2.6626 - val_dice_coefficient: 0.0653
#
# Epoch 00004: val_dice_coefficient improved from 0.05978 to 0.06535, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 5/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.6692 - dice_coefficient: 0.3951 - val_loss: 0.8728 - val_dice_coefficient: 0.2116
#
# Epoch 00005: val_dice_coefficient improved from 0.06535 to 0.21161, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 6/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5893 - dice_coefficient: 0.4634 - val_loss: 1.0139 - val_dice_coefficient: 0.2150
#
# Epoch 00006: val_dice_coefficient improved from 0.21161 to 0.21498, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 7/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5912 - dice_coefficient: 0.4595 - val_loss: 0.7307 - val_dice_coefficient: 0.3334
#
# Epoch 00007: val_dice_coefficient improved from 0.21498 to 0.33336, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 8/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5599 - dice_coefficient: 0.4889 - val_loss: 0.6739 - val_dice_coefficient: 0.3927
#
# Epoch 00008: val_dice_coefficient improved from 0.33336 to 0.39271, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 9/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5248 - dice_coefficient: 0.5194 - val_loss: 0.9536 - val_dice_coefficient: 0.1405
#
# Epoch 00009: val_dice_coefficient did not improve from 0.39271
# Epoch 10/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5307 - dice_coefficient: 0.5128 - val_loss: 0.5737 - val_dice_coefficient: 0.4760
#
# Epoch 00010: val_dice_coefficient improved from 0.39271 to 0.47601, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 11/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5099 - dice_coefficient: 0.5327 - val_loss: 0.5443 - val_dice_coefficient: 0.4994
#
# Epoch 00011: val_dice_coefficient improved from 0.47601 to 0.49940, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 12/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.5004 - dice_coefficient: 0.5398 - val_loss: 1.3898 - val_dice_coefficient: 0.1113
#
# Epoch 00012: val_dice_coefficient did not improve from 0.49940
# Epoch 13/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4986 - dice_coefficient: 0.5421 - val_loss: 0.5866 - val_dice_coefficient: 0.4611
#
# Epoch 00013: val_dice_coefficient did not improve from 0.49940
# Epoch 14/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4854 - dice_coefficient: 0.5530 - val_loss: 0.5142 - val_dice_coefficient: 0.5270
#
# Epoch 00014: val_dice_coefficient improved from 0.49940 to 0.52702, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 15/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4873 - dice_coefficient: 0.5514 - val_loss: 0.5037 - val_dice_coefficient: 0.5379
#
# Epoch 00015: val_dice_coefficient improved from 0.52702 to 0.53787, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 16/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4825 - dice_coefficient: 0.5553 - val_loss: 0.5209 - val_dice_coefficient: 0.5231
#
# Epoch 00016: val_dice_coefficient did not improve from 0.53787
# Epoch 17/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4731 - dice_coefficient: 0.5629 - val_loss: 0.4767 - val_dice_coefficient: 0.5632
#
# Epoch 00017: val_dice_coefficient improved from 0.53787 to 0.56317, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 18/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4718 - dice_coefficient: 0.5644 - val_loss: 0.5431 - val_dice_coefficient: 0.5019
#
# Epoch 00018: val_dice_coefficient did not improve from 0.56317
# Epoch 19/30
# 333/333 [==============================] - 546s 2s/step - loss: 0.4590 - dice_coefficient: 0.5763 - val_loss: 0.4872 - val_dice_coefficient: 0.5528
#
# Epoch 00019: val_dice_coefficient did not improve from 0.56317
# Epoch 20/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4460 - dice_coefficient: 0.5883 - val_loss: 0.8733 - val_dice_coefficient: 0.2646
#
# Epoch 00020: val_dice_coefficient did not improve from 0.56317
# Epoch 21/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4612 - dice_coefficient: 0.5743 - val_loss: 0.7688 - val_dice_coefficient: 0.3231
#
# Epoch 00021: val_dice_coefficient did not improve from 0.56317
# Epoch 22/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4631 - dice_coefficient: 0.5733 - val_loss: 0.5272 - val_dice_coefficient: 0.5175
#
# Epoch 00022: val_dice_coefficient did not improve from 0.56317
# Epoch 23/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4364 - dice_coefficient: 0.5977 - val_loss: 0.5315 - val_dice_coefficient: 0.5162
#
# Epoch 00023: val_dice_coefficient did not improve from 0.56317
# Epoch 24/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4185 - dice_coefficient: 0.6145 - val_loss: 0.4808 - val_dice_coefficient: 0.5600
#
# Epoch 00024: val_dice_coefficient did not improve from 0.56317
# Epoch 25/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4146 - dice_coefficient: 0.6177 - val_loss: 0.5661 - val_dice_coefficient: 0.4857
#
# Epoch 00025: val_dice_coefficient did not improve from 0.56317
# Epoch 26/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4179 - dice_coefficient: 0.6156 - val_loss: 0.6712 - val_dice_coefficient: 0.3902
#
# Epoch 00026: val_dice_coefficient did not improve from 0.56317
# Epoch 27/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.4125 - dice_coefficient: 0.6178 - val_loss: 0.4475 - val_dice_coefficient: 0.5921
#
# Epoch 00027: val_dice_coefficient improved from 0.56317 to 0.59213, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 28/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.3793 - dice_coefficient: 0.6505 - val_loss: 0.5239 - val_dice_coefficient: 0.5278
#
# Epoch 00028: val_dice_coefficient did not improve from 0.59213
# Epoch 29/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.3836 - dice_coefficient: 0.6457 - val_loss: 0.6583 - val_dice_coefficient: 0.4033
#
# Epoch 00029: val_dice_coefficient did not improve from 0.59213
# Epoch 30/30
# 333/333 [==============================] - 545s 2s/step - loss: 0.3812 - dice_coefficient: 0.6481 - val_loss: 0.4746 - val_dice_coefficient: 0.5684
#
# Epoch 00030: val_dice_coefficient did not improve from 0.59213

# %%
# Visualizing history for dice_coefficient
plt.figure(figsize=(12, 8))
plt.plot(history.history['dice_coefficient'])
plt.plot(history.history['val_dice_coefficient'])
plt.title('model dice_coefficient')
plt.ylabel('dice_coefficient')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()
# Visualizing history for loss
plt.figure(figsize=(12, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('bce_dice_loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()

# %%
# saving history data for first 30 epochs in csv file
history1 = pd.DataFrame(history.history)
history1.to_csv(path + "data/history1-linknet_withResnet.csv", index=True)
# saving model(weights upto 30 epochs)
model.save(path+'linknet_withResnet-30epochs.h5')

# %% [markdown]
# ### 8.6 Traing Model (30-60 epochs)

# %%
#loading saved weights of model trained upto 30 epochs
model.load_weights(path + 'linknet_withResnet-30epochs.h5')
# fit model
history = model.fit(train_batches,validation_data=validtn_batches, epochs = 30, callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 333/333 [==============================] - 5762s 17s/step - loss: 0.3804 - dice_coefficient: 0.6484 - val_loss: 0.4371 - val_dice_coefficient: 0.6040
#
# Epoch 00001: val_dice_coefficient improved from -inf to 0.60404, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 2/30
# 333/333 [==============================] - 995s 3s/step - loss: 0.3714 - dice_coefficient: 0.6571 - val_loss: 0.4813 - val_dice_coefficient: 0.5626
#
# Epoch 00002: val_dice_coefficient did not improve from 0.60404
# Epoch 3/30
# 333/333 [==============================] - 995s 3s/step - loss: 0.3561 - dice_coefficient: 0.6709 - val_loss: 0.6725 - val_dice_coefficient: 0.4044
#
# Epoch 00003: val_dice_coefficient did not improve from 0.60404
# Epoch 4/30
# 333/333 [==============================] - 994s 3s/step - loss: 0.3630 - dice_coefficient: 0.6649 - val_loss: 0.4358 - val_dice_coefficient: 0.6002
#
# Epoch 00004: val_dice_coefficient did not improve from 0.60404
# Epoch 5/30
# 333/333 [==============================] - 996s 3s/step - loss: 0.3625 - dice_coefficient: 0.6657 - val_loss: 0.6049 - val_dice_coefficient: 0.4465
#
# Epoch 00005: val_dice_coefficient did not improve from 0.60404
# Epoch 6/30
# 333/333 [==============================] - 998s 3s/step - loss: 0.3530 - dice_coefficient: 0.6735 - val_loss: 0.4603 - val_dice_coefficient: 0.5798
#
# Epoch 00006: val_dice_coefficient did not improve from 0.60404
# Epoch 7/30
# 333/333 [==============================] - 998s 3s/step - loss: 0.3408 - dice_coefficient: 0.6852 - val_loss: 0.4284 - val_dice_coefficient: 0.6067
#
# Epoch 00007: val_dice_coefficient improved from 0.60404 to 0.60669, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 8/30
# 333/333 [==============================] - 995s 3s/step - loss: 0.3421 - dice_coefficient: 0.6850 - val_loss: 0.5960 - val_dice_coefficient: 0.4691
#
# Epoch 00008: val_dice_coefficient did not improve from 0.60669
# Epoch 9/30
# 333/333 [==============================] - 994s 3s/step - loss: 0.3450 - dice_coefficient: 0.6814 - val_loss: 0.4406 - val_dice_coefficient: 0.5988
#
# Epoch 00009: val_dice_coefficient did not improve from 0.60669
# Epoch 10/30
# 333/333 [==============================] - 997s 3s/step - loss: 0.3315 - dice_coefficient: 0.6934 - val_loss: 0.3940 - val_dice_coefficient: 0.6393
#
# Epoch 00010: val_dice_coefficient improved from 0.60669 to 0.63928, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 11/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.3390 - dice_coefficient: 0.6860 - val_loss: 0.5618 - val_dice_coefficient: 0.4883
#
# Epoch 00011: val_dice_coefficient did not improve from 0.63928
# Epoch 12/30
# 333/333 [==============================] - 1003s 3s/step - loss: 0.3289 - dice_coefficient: 0.6958 - val_loss: 0.5709 - val_dice_coefficient: 0.4890
#
# Epoch 00012: val_dice_coefficient did not improve from 0.63928
# Epoch 13/30
# 333/333 [==============================] - 1002s 3s/step - loss: 0.3253 - dice_coefficient: 0.6994 - val_loss: 0.4219 - val_dice_coefficient: 0.6160
#
# Epoch 00013: val_dice_coefficient did not improve from 0.63928
# Epoch 14/30
# 333/333 [==============================] - 1004s 3s/step - loss: 0.3213 - dice_coefficient: 0.7033 - val_loss: 0.3605 - val_dice_coefficient: 0.6686
#
# Epoch 00014: val_dice_coefficient improved from 0.63928 to 0.66861, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 15/30
# 333/333 [==============================] - 1003s 3s/step - loss: 0.3169 - dice_coefficient: 0.7068 - val_loss: 0.3562 - val_dice_coefficient: 0.6727
#
# Epoch 00015: val_dice_coefficient improved from 0.66861 to 0.67271, saving model to /content/drive/MyDrive/cs2/linknet_withResnet.h5
# Epoch 16/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.3134 - dice_coefficient: 0.7102 - val_loss: 0.3818 - val_dice_coefficient: 0.6505
#
# Epoch 00016: val_dice_coefficient did not improve from 0.67271
# Epoch 17/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.3079 - dice_coefficient: 0.7157 - val_loss: 0.3738 - val_dice_coefficient: 0.6584
#
# Epoch 00017: val_dice_coefficient did not improve from 0.67271
# Epoch 18/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.3104 - dice_coefficient: 0.7133 - val_loss: 0.4001 - val_dice_coefficient: 0.6356
#
# Epoch 00018: val_dice_coefficient did not improve from 0.67271
# Epoch 19/30
# 333/333 [==============================] - 999s 3s/step - loss: 0.3059 - dice_coefficient: 0.7173 - val_loss: 0.3963 - val_dice_coefficient: 0.6391
#
# Epoch 00019: val_dice_coefficient did not improve from 0.67271
# Epoch 20/30
# 333/333 [==============================] - 999s 3s/step - loss: 0.3075 - dice_coefficient: 0.7168 - val_loss: 0.3878 - val_dice_coefficient: 0.6442
#
# Epoch 00020: val_dice_coefficient did not improve from 0.67271
# Epoch 21/30
# 333/333 [==============================] - 999s 3s/step - loss: 0.2923 - dice_coefficient: 0.7297 - val_loss: 0.4863 - val_dice_coefficient: 0.5566
#
# Epoch 00021: val_dice_coefficient did not improve from 0.67271
# Epoch 22/30
# 333/333 [==============================] - 999s 3s/step - loss: 0.3007 - dice_coefficient: 0.7230 - val_loss: 0.4682 - val_dice_coefficient: 0.5777
#
# Epoch 00022: val_dice_coefficient did not improve from 0.67271
# Epoch 23/30
# 333/333 [==============================] - 999s 3s/step - loss: 0.2919 - dice_coefficient: 0.7307 - val_loss: 0.7262 - val_dice_coefficient: 0.3745
#
# Epoch 00023: val_dice_coefficient did not improve from 0.67271
# Epoch 24/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.2882 - dice_coefficient: 0.7339 - val_loss: 0.5360 - val_dice_coefficient: 0.5178
#
# Epoch 00024: val_dice_coefficient did not improve from 0.67271
# Epoch 25/30
# 333/333 [==============================] - 1001s 3s/step - loss: 0.2889 - dice_coefficient: 0.7344 - val_loss: 0.3646 - val_dice_coefficient: 0.6675
#
# Epoch 00025: val_dice_coefficient did not improve from 0.67271
# Epoch 26/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.2864 - dice_coefficient: 0.7353 - val_loss: 0.3759 - val_dice_coefficient: 0.6579
#
# Epoch 00026: val_dice_coefficient did not improve from 0.67271
# Epoch 27/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.2787 - dice_coefficient: 0.7427 - val_loss: 0.4317 - val_dice_coefficient: 0.6088
#
# Epoch 00027: val_dice_coefficient did not improve from 0.67271
# Epoch 28/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.2759 - dice_coefficient: 0.7462 - val_loss: 0.4196 - val_dice_coefficient: 0.6189
#
# Epoch 00028: val_dice_coefficient did not improve from 0.67271
# Epoch 29/30
# 333/333 [==============================] - 1000s 3s/step - loss: 0.2799 - dice_coefficient: 0.7418 - val_loss: 0.3933 - val_dice_coefficient: 0.6429
#
# Epoch 00029: val_dice_coefficient did not improve from 0.67271
# Epoch 30/30
# 333/333 [==============================] - 1001s 3s/step - loss: 0.2687 - dice_coefficient: 0.7517 - val_loss: 0.3666 - val_dice_coefficient: 0.6662
#
# Epoch 00030: val_dice_coefficient did not improve from 0.67271

# %%
# saving history data for 31-60 epochs in csv file
history2 = pd.DataFrame(history.history)
history2.to_csv(path + "data/history2-linknet_withResnet.csv", index=True)
# saving model(weights upto 60 epochs)
model.save(path+'linknet_withResnet-31-60epochs.h5')

# %%
#loading saved history of 1-30 epochs
history1 = pd.read_csv(path + "data/history1-linknet_withResnet.csv")
#loading saved history of 30-60 epochs
history2 = pd.read_csv(path + "data/history2-linknet_withResnet.csv")

# Visualizing history(1-60 epochs) for dice_coefficient
plt.figure(figsize=(12, 8))
plt.plot(history1['dice_coefficient'].tolist() + history2['dice_coefficient'].tolist())
plt.plot(history1['val_dice_coefficient'].tolist() + history2['val_dice_coefficient'].tolist())
plt.title('model dice_coefficient')
plt.ylabel('dice_coefficient')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()
# Visualizing history(1-60 epochs) for loss
plt.figure(figsize=(12, 8))
plt.plot(history1['loss'].tolist() + history2['loss'].tolist())
plt.plot(history1['val_loss'].tolist() + history2['val_loss'].tolist())
plt.title('model loss')
plt.ylabel('bce_dice_loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 8.7 Visualizing Model Predictions

# %%
# evaluating model(best weights) with the validation batch
model.load_weights(path + 'linknet_withResnet.h5')
loss, dc= model.evaluate(validtn_batches,verbose=1)
print('loss:',loss, 'dice_coefficient:',dc)
# Out:
# 58/58 [==============================] - 856s 14s/step - loss: 0.3498 - dice_coefficient: 0.6787
# loss: 0.3561689257621765 dice_coefficient: 0.672707200050354

# %%
#defining function to display GroundTruth & Predicted mask images for a given imageId
def visualize_model_prediction(img_id):
    fig, axs = plt.subplots(4, 3, figsize=(16,8))
    img_obj = cv2.imread(path+'data/train_images/'+ img_id)
    masks_actual = full_data[full_data['ImageId'] == img_id]
    x = np.empty((1,256,1600,3),dtype=np.float32) # image place-holders
    x[0,] = Image.open(path+'data/train_images/' + img_id)
    masks_predicted = model.predict(x)
    for i in range(4):
        axs[i,0].imshow(img_obj)
        axs[i,0].set_title(img_id)
        axs[i,1].imshow(rle2mask(masks_actual['rle_'+str(i+1)].iloc[0]))
        axs[i,1].set_title("Actual mask for Class '{}'".format(i+1) )
        axs[i,2].imshow(masks_predicted[0,:,:,i])
        axs[i,2].set_title("Predicted mask for Class '{}'".format(i+1))
    plt.show()

# %%
visualize_model_prediction('0002cc93b.jpg')

# %%
visualize_model_prediction('4d38c353e.jpg')

# %% [markdown]
# ### 8.8 Preparing Data for submission

# %%
class PredictDataGenerator(tf.keras.utils.Sequence):
    def __init__(self,dataframe, list_idcs, batch_size=32, ):
        self.batch_size = batch_size
        self.df = dataframe
        self.list_idcs = list_idcs
        self.indices = self.df.index.tolist()
        self.rem = len(self.list_idcs) % (self.batch_size)
        self.on_epoch_end()

    def __len__(self):
         return len(self.list_idcs) // (self.batch_size)
#         if (self.rem) == 0:
#             return len(self.list_idcs) // (self.batch_size)
#         else:
#             return (len(self.list_idcs) // (self.batch_size) )+1

    def __getitem__(self, index):
        index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         if ((index + 1) * self.batch_size) < len(self.list_idcs):
#             index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         else:
#             index = self.indices[index * self.batch_size: (index * self.batch_size)+ self.rem]
        batch = [self.list_idcs[k] for k in index]
        
        X = self.__get_data(batch)
         
        return X
    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))

    def __get_data(self, batch):
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
              
        for i, id in enumerate(batch):
          img = Image.open(path + 'data/test_images/' + str(self.df['ImageId'].loc[id]))
          X[i,] = img#input image

        return X

# %%
test_img_IDs = list(os.listdir(path + 'data/test_images/'))
test_imgsIds_df = pd.DataFrame({'ImageId': test_img_IDs})
print(len(test_imgsIds_df))
test_imgsIds_df.head()
# Out:
# 5506
#          ImageId
# 0  d3dcedbd7.jpg
# 1  db7cff638.jpg
# 2  d3764cee5.jpg
# 3  d387d301f.jpg
# 4  d221d2a3f.jpg

# %%
SubmissionDf = pd.DataFrame(columns = ['ImageId','EncodedPixels','ClassId'])

# %%
for i in range(0,len(test_imgsIds_df),320):
    batch_idcs =  list(range(i, min(test_imgsIds_df.shape[0], i + 320)))#.iloc[batch_idcs]
    if len(batch_idcs)== 320:        
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs)
    else:
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs,
                                             batch_size= len(batch_idcs))
    #print(len(test_subbatch))
    subbatch_pred_masks = model.predict(test_subbatch)
    #print(len(subbatch_pred_masks))
    #break
    for j, idx in tqdm(enumerate(batch_idcs)):
        filename = test_imgsIds_df['ImageId'].iloc[idx]
        rle1 = mask2rle(subbatch_pred_masks[j,:,:,0].round().astype(int))
        rle2 = mask2rle(subbatch_pred_masks[j,:,:,1].round().astype(int))
        rle3 = mask2rle(subbatch_pred_masks[j,:,:,2].round().astype(int))
        rle4 = mask2rle(subbatch_pred_masks[j,:,:,3].round().astype(int))
        df = pd.DataFrame({'ImageId':[filename]*4,
                      'EncodedPixels': [rle1,rle2,rle3,rle4],
                      'ClassId':['1', '2', '3', '4']})
        SubmissionDf = SubmissionDf.append(df,ignore_index=True)
# Out:
# 320it [00:03, 82.35it/s]
# 320it [00:04, 68.53it/s]
# 320it [00:04, 67.76it/s]
# 320it [00:04, 67.64it/s]
# 320it [00:04, 68.45it/s]
# 320it [00:04, 67.87it/s]
# 320it [00:04, 68.06it/s]
# 320it [00:04, 71.14it/s]
# 320it [00:04, 68.20it/s]
# 320it [00:04, 68.32it/s]
# 320it [00:04, 68.02it/s]
# 320it [00:04, 69.36it/s]
# 320it [00:04, 67.87it/s]
# 320it [00:04, 68.65it/s]
# 320it [00:04, 68.23it/s]
# 320it [00:04, 68.30it/s]
# 320it [00:04, 68.33it/s]
# 66it [00:00, 67.21it/s]

# %%
SubmissionDf.sort_values(by=['ImageId', 'ClassId'], inplace=True)
SubmissionDf['ImageId_ClassId'] = SubmissionDf['ImageId'] + '_' + SubmissionDf['ClassId']
print(SubmissionDf.shape)
SubmissionDf.head(10)
# Out:
# (22024, 4)
#              ImageId  ...  ImageId_ClassId
# 20016  0000f269f.jpg  ...  0000f269f.jpg_1
# 20017  0000f269f.jpg  ...  0000f269f.jpg_2
# 20018  0000f269f.jpg  ...  0000f269f.jpg_3
# 20019  0000f269f.jpg  ...  0000f269f.jpg_4
# 20004  000ccc2ac.jpg  ...  000ccc2ac.jpg_1
# 20005  000ccc2ac.jpg  ...  000ccc2ac.jpg_2
# 20006  000ccc2ac.jpg  ...  000ccc2ac.jpg_3
# 20007  000ccc2ac.jpg  ...  000ccc2ac.jpg_4
# 20012  002451917.jpg  ...  002451917.jpg_1
# 20013  002451917.jpg  ...  002451917.jpg_2
#
# [10 rows x 4 columns]

# %%
SubmissionDf.to_csv(path+'submission-linknet_withResnet.csv', index=False)

# %%
# dot_img_file = '/tmp/model_1.png'
# tf.keras.utils.plot_model(model2, to_file=dot_img_file, show_shapes=True)

# %% [markdown]
# ### 8.9 Kaggle Submission Score

# %%
#Kaggle Score
from IPython.display import Image
Image(filename='linknet with resnet.JPG')
