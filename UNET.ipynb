# %% [markdown]
# ## 5. UNET

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import os
from tqdm import tqdm

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Dropout, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.layers import Concatenate, Add
from tensorflow.keras import Input, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

# %% [markdown]
# ### 5.1 Loading Data

# %%
path = '/content/drive/MyDrive/cs2/'

# %%
full_data = pd.read_csv(path+'data/full_data.csv').fillna('')
full_data.head()
# Out:
#          ImageId  ... rle_4
# 0  0002cc93b.jpg  ...
# 1  00031f466.jpg  ...
# 2  000418bfc.jpg  ...
# 3  000789191.jpg  ...
# 4  0007a71bf.jpg  ...
#
# [5 rows x 5 columns]

# %%
#splitting the data into train & cv
from sklearn.model_selection import train_test_split
train_data, validtn_data = train_test_split(full_data, test_size=0.15, random_state=42)
print(train_data.shape)
print(validtn_data.shape)
# Out:
# (10682, 5)
# (1886, 5)

# %%
# Saving the train and validation data in csv files for future use
train_data.to_csv(path + "data/train_data.csv", index=False)
validtn_data.to_csv(path + "data/validtn_data.csv", index=False)

# %%
#loading train and validation data
train_data = pd.read_csv(path + "data/train_data.csv").fillna('')
validtn_data = pd.read_csv(path + "data/validtn_data.csv").fillna('')

# %% [markdown]
# ### 5.2 Data Generator Implementation

# %%
# Implementing custom data generator
#https://towardsdatascience.com/implementing-custom-data-generators-in-keras-de56f013581c
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size=32, num_classes=None, shuffle=True, preprocess=None):
        self.batch_size = batch_size
        self.df = dataframe
        self.indices = self.df.index.tolist()
        self.preprocess = preprocess
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return len(self.indices) // (self.batch_size)

    def __getitem__(self, index):
        index = self.index[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def __get_data(self, batch):
        train_datagen = ImageDataGenerator()
        param = {'flip_horizontal':True, 'samplewise_std_normalization' : True,
                 'width_shift_range':0.1, 'height_shift_range':0.1,}
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
        Y = np.empty((self.batch_size,256,1600,4),dtype=np.float32)# 4 masks place-holders
              
        for i, id in enumerate(batch):
          img = Image.open(path+'data/train_images/' + str(self.df['ImageId'].loc[id]))
          X[i,] = train_datagen.apply_transform(x = img, transform_parameters = param)#input image
          for j in range(4): #looping for each class
                mask = rle2mask(self.df['rle_'+str(j+1)].loc[id])
                Y[i,:,:,j] = train_datagen.apply_transform(x = mask, transform_parameters = param)#mask for each class
                
        # preprocess input
        if self.preprocess!=None: X = self.preprocess(X)

        return X, Y

# %% [markdown]
# ### 5.3 Utility Functions

# %%
#https://www.kaggle.com/titericz/building-and-visualizing-masks
#https://www.kaggle.com/paulorzp/rle-functions-run-lenght-encode-decode

#defining function for converting EncodedPixels(rle: run length encoding) to mask
def rle2mask(rle_string, img_shape=(256,1600)):
    '''
    input: EncodedPixels (run-length-encoded) string & image shape:-(width,height)
    output: mask in numpy.ndarray format with shape (256,1600)
    '''
    rle_array = np.array([int(s)for s in rle_string.split()])
    starts_array = rle_array[::2]-1
    lengths_array = rle_array[1::2]
    mask_array = np.zeros(img_shape[0]*img_shape[1],dtype=np.uint8)
    #print(starts_array,lengths_array)
    for i in range(len(starts_array)):
        mask_array[starts_array[i]:starts_array[i]+lengths_array[i]] = 1
    #order='F' because encoded pixels are numbered from top to bottom, then left to right
    return mask_array.reshape(img_shape, order = 'F')

#defining function for converting given mask to EncodedPixels(rle: run length encoding)
def mask2rle(mask_array):
    '''
    input: mask in numpy.ndarray format
    output: EncodedPixels (run-length-encoded) string
    '''
    mask_array = mask_array.T.flatten()
    mask_array = np.concatenate([[0], mask_array, [0]])
    rle_array = np.where(mask_array[1:]!=mask_array[:-1])[0]+1
    rle_array[1::2] -= rle_array[::2]
    rle_string = ' '.join(map(str,rle_array))
    return rle_string

#defining function for calculation of metric dice coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.math.reduce_sum(y_true_f * y_pred_f)
    smoothing_const = 1e-9
    return (2. * intersection + smoothing_const) / (tf.math.reduce_sum(y_true_f) + tf.math.reduce_sum(y_pred_f) + smoothing_const)

#defining function for calculation of dice coefficient
def dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return (1-dice_coefficient(y_true, y_pred))

#defining function for calculation of loss function: binary cross entropy + dice loss
def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    return binary_crossentropy(y_true, y_pred) + (1-dice_coefficient(y_true, y_pred))

# %% [markdown]
# ### 5.4 Defining Unet Architecture

# %%
# defining Unet architecture
# https://arxiv.org/abs/1505.04597
# https://towardsdatascience.com/understanding-semantic-segmentation-with-unet-6be4f42d4b47
# https://github.com/hlamba28/UNET-TGS

def conv2D_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True ):
    """function to pass Input_tensor through 2- Conv2D layers configured as per the input parameters"""
    # first Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    # second Conv2D layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
            kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

    return x


def Unet_Model(input_image, n_filters = 16, dropout = 0.1, batchnorm = True):
    # Encoder (Contraction Path)
    E1 = conv2D_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(E1)
    p1 = Dropout(dropout)(p1)

    E2 = conv2D_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(E2)
    p2 = Dropout(dropout)(p2)

    E3 = conv2D_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(E3)
    p3 = Dropout(dropout)(p3)

    E4 = conv2D_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(E4)
    p4 = Dropout(dropout)(p4)

    E5 = conv2D_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

    # Decoder (Expansive Path)
    D6 = Conv2DTranspose(n_filters * 8, kernel_size = (3, 3), strides = (2, 2), padding = 'same')(E5)
    D6 = Concatenate()([D6, E4])
    D6 = Dropout(dropout)(D6)
    E6 = conv2D_block(D6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

    D7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(E6)
    D7 = Concatenate()([D7, E3])
    D7 = Dropout(dropout)(D7)
    E7 = conv2D_block(D7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

    D8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(E7)
    D8 = Concatenate()([D8, E2])
    D8 = Dropout(dropout)(D8)
    E8 = conv2D_block(D8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

    D9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(E8)
    D9 = Concatenate()([D9, E1])
    D9 = Dropout(dropout)(D9)
    E9 = conv2D_block(D9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

    outputs = Conv2D(4, (1, 1), activation='sigmoid')(E9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
#configuring input tensor
input_img = Input((256, 1600, 3), name='img')

model = Unet_Model(input_img, n_filters=8, dropout=0.2, batchnorm=True)
model.compile(optimizer=Adam(), loss=bce_dice_loss, metrics=[dice_coefficient])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 1600, 3 0
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 1600, 8) 224         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 1600, 8) 32          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 1600, 8) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 800, 8)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128, 800, 8)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 800, 16) 1168        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 800, 16) 64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 128, 800, 16) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 400, 16)  0           activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 400, 16)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 400, 32)  4640        dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 400, 32)  128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 400, 32)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 200, 32)  0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 200, 32)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 200, 64)  18496       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 200, 64)  256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 200, 64)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 100, 64)  0           activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 100, 64)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 100, 128) 73856       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 100, 128) 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 100, 128) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 200, 64)  73792       activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 200, 128) 0           conv2d_transpose_1[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 200, 128) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 200, 64)  73792       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 200, 64)  256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 200, 64)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 400, 32)  18464       activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 400, 64)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 400, 64)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 400, 32)  18464       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 400, 32)  128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 400, 32)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 800, 16) 4624        activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 800, 32) 0           conv2d_transpose_3[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 800, 32) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 800, 16) 4624        dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 800, 16) 64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 128, 800, 16) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 1600, 8) 1160        activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 1600, 16 0           conv2d_transpose_4[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256, 1600, 16 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 1600, 8) 1160        dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 1600, 8) 32          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 256, 1600, 8) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 1600, 4) 36          activation_27[0][0]
# ==================================================================================================
# Total params: 295,972
# Trainable params: 295,236
# Non-trainable params: 736
# __________________________________________________________________________________________________

# %%
#loading train & validation data using DataGenerator class defined
train_batches = DataGenerator(train_data,shuffle=True)
validtn_batches = DataGenerator(validtn_data,shuffle=False)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import datetime, os

# #tensorboard for visualizing loss & metric summary 
# logdir = path+"logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(logdir)

#defining ModelCheckpoint to make a checkpoint when validation dice coefficient improves
checkpoints = ModelCheckpoint(path+'unet.h5', \
                              monitor='val_dice_coefficient', verbose=1, save_best_only=True, mode='max')

#adding ModelCheckpoint & TensorBoard to callback functions list
callbacks_list = [checkpoints]

# %% [markdown]
# ### 5.5 Traing Model

# %%
# fit model
history = model.fit(train_batches,validation_data=validtn_batches, epochs = 60, callbacks=callbacks_list)
# Out:
# Epoch 1/60
# 333/333 [==============================] - 5022s 15s/step - loss: 1.5147 - dice_coefficient: 0.0203 - val_loss: 1.1970 - val_dice_coefficient: 0.0259
#
# Epoch 00001: val_dice_coefficient improved from -inf to 0.02592, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 2/60
# 333/333 [==============================] - 388s 1s/step - loss: 1.0711 - dice_coefficient: 0.0589 - val_loss: 0.8437 - val_dice_coefficient: 0.2004
#
# Epoch 00002: val_dice_coefficient improved from 0.02592 to 0.20035, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 3/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.7187 - dice_coefficient: 0.3209 - val_loss: 0.6084 - val_dice_coefficient: 0.4363
#
# Epoch 00003: val_dice_coefficient improved from 0.20035 to 0.43634, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 4/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5785 - dice_coefficient: 0.4591 - val_loss: 0.6118 - val_dice_coefficient: 0.4361
#
# Epoch 00004: val_dice_coefficient did not improve from 0.43634
# Epoch 5/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5575 - dice_coefficient: 0.4819 - val_loss: 0.6029 - val_dice_coefficient: 0.4483
#
# Epoch 00005: val_dice_coefficient improved from 0.43634 to 0.44833, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 6/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5412 - dice_coefficient: 0.4987 - val_loss: 0.5650 - val_dice_coefficient: 0.4795
#
# Epoch 00006: val_dice_coefficient improved from 0.44833 to 0.47950, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 7/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5367 - dice_coefficient: 0.5044 - val_loss: 0.5984 - val_dice_coefficient: 0.4548
#
# Epoch 00007: val_dice_coefficient did not improve from 0.47950
# Epoch 8/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5268 - dice_coefficient: 0.5150 - val_loss: 0.5959 - val_dice_coefficient: 0.4544
#
# Epoch 00008: val_dice_coefficient did not improve from 0.47950
# Epoch 9/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5271 - dice_coefficient: 0.5126 - val_loss: 0.5461 - val_dice_coefficient: 0.4979
#
# Epoch 00009: val_dice_coefficient improved from 0.47950 to 0.49790, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 10/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5130 - dice_coefficient: 0.5268 - val_loss: 0.5526 - val_dice_coefficient: 0.4964
#
# Epoch 00010: val_dice_coefficient did not improve from 0.49790
# Epoch 11/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5153 - dice_coefficient: 0.5253 - val_loss: 0.5421 - val_dice_coefficient: 0.5045
#
# Epoch 00011: val_dice_coefficient improved from 0.49790 to 0.50452, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 12/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4975 - dice_coefficient: 0.5395 - val_loss: 0.5640 - val_dice_coefficient: 0.4861
#
# Epoch 00012: val_dice_coefficient did not improve from 0.50452
# Epoch 13/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.5103 - dice_coefficient: 0.5272 - val_loss: 0.5300 - val_dice_coefficient: 0.5163
#
# Epoch 00013: val_dice_coefficient improved from 0.50452 to 0.51634, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 14/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4982 - dice_coefficient: 0.5397 - val_loss: 0.5482 - val_dice_coefficient: 0.5020
#
# Epoch 00014: val_dice_coefficient did not improve from 0.51634
# Epoch 15/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4961 - dice_coefficient: 0.5406 - val_loss: 0.7070 - val_dice_coefficient: 0.3533
#
# Epoch 00015: val_dice_coefficient did not improve from 0.51634
# Epoch 16/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4803 - dice_coefficient: 0.5555 - val_loss: 0.5158 - val_dice_coefficient: 0.5275
#
# Epoch 00016: val_dice_coefficient improved from 0.51634 to 0.52748, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 17/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4922 - dice_coefficient: 0.5433 - val_loss: 0.5087 - val_dice_coefficient: 0.5350
#
# Epoch 00017: val_dice_coefficient improved from 0.52748 to 0.53500, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 18/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4903 - dice_coefficient: 0.5452 - val_loss: 0.5220 - val_dice_coefficient: 0.5240
#
# Epoch 00018: val_dice_coefficient did not improve from 0.53500
# Epoch 19/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4885 - dice_coefficient: 0.5476 - val_loss: 0.5173 - val_dice_coefficient: 0.5296
#
# Epoch 00019: val_dice_coefficient did not improve from 0.53500
# Epoch 20/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4829 - dice_coefficient: 0.5524 - val_loss: 0.5061 - val_dice_coefficient: 0.5416
#
# Epoch 00020: val_dice_coefficient improved from 0.53500 to 0.54165, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 21/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4817 - dice_coefficient: 0.5539 - val_loss: 0.5105 - val_dice_coefficient: 0.5376
#
# Epoch 00021: val_dice_coefficient did not improve from 0.54165
# Epoch 22/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4694 - dice_coefficient: 0.5656 - val_loss: 0.5216 - val_dice_coefficient: 0.5269
#
# Epoch 00022: val_dice_coefficient did not improve from 0.54165
# Epoch 23/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4675 - dice_coefficient: 0.5660 - val_loss: 0.5243 - val_dice_coefficient: 0.5226
#
# Epoch 00023: val_dice_coefficient did not improve from 0.54165
# Epoch 24/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4704 - dice_coefficient: 0.5627 - val_loss: 0.4892 - val_dice_coefficient: 0.5501
#
# Epoch 00024: val_dice_coefficient improved from 0.54165 to 0.55010, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 25/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4724 - dice_coefficient: 0.5613 - val_loss: 0.4862 - val_dice_coefficient: 0.5571
#
# Epoch 00025: val_dice_coefficient improved from 0.55010 to 0.55707, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 26/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4716 - dice_coefficient: 0.5635 - val_loss: 0.4980 - val_dice_coefficient: 0.5463
#
# Epoch 00026: val_dice_coefficient did not improve from 0.55707
# Epoch 27/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4598 - dice_coefficient: 0.5748 - val_loss: 0.4911 - val_dice_coefficient: 0.5531
#
# Epoch 00027: val_dice_coefficient did not improve from 0.55707
# Epoch 28/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4514 - dice_coefficient: 0.5822 - val_loss: 0.4655 - val_dice_coefficient: 0.5766
#
# Epoch 00028: val_dice_coefficient improved from 0.55707 to 0.57658, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 29/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4408 - dice_coefficient: 0.5924 - val_loss: 0.5639 - val_dice_coefficient: 0.4883
#
# Epoch 00029: val_dice_coefficient did not improve from 0.57658
# Epoch 30/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4389 - dice_coefficient: 0.5937 - val_loss: 0.4656 - val_dice_coefficient: 0.5758
#
# Epoch 00030: val_dice_coefficient did not improve from 0.57658
# Epoch 31/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4300 - dice_coefficient: 0.6027 - val_loss: 0.4399 - val_dice_coefficient: 0.5976
#
# Epoch 00031: val_dice_coefficient improved from 0.57658 to 0.59761, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 32/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4251 - dice_coefficient: 0.6072 - val_loss: 0.4737 - val_dice_coefficient: 0.5692
#
# Epoch 00032: val_dice_coefficient did not improve from 0.59761
# Epoch 33/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4325 - dice_coefficient: 0.5996 - val_loss: 0.4511 - val_dice_coefficient: 0.5879
#
# Epoch 00033: val_dice_coefficient did not improve from 0.59761
# Epoch 34/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4191 - dice_coefficient: 0.6119 - val_loss: 0.4315 - val_dice_coefficient: 0.6050
#
# Epoch 00034: val_dice_coefficient improved from 0.59761 to 0.60499, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 35/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4329 - dice_coefficient: 0.5986 - val_loss: 0.4352 - val_dice_coefficient: 0.6034
#
# Epoch 00035: val_dice_coefficient did not improve from 0.60499
# Epoch 36/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4324 - dice_coefficient: 0.5992 - val_loss: 0.4628 - val_dice_coefficient: 0.5769
#
# Epoch 00036: val_dice_coefficient did not improve from 0.60499
# Epoch 37/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4168 - dice_coefficient: 0.6148 - val_loss: 0.4254 - val_dice_coefficient: 0.6118
#
# Epoch 00037: val_dice_coefficient improved from 0.60499 to 0.61184, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 38/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4208 - dice_coefficient: 0.6107 - val_loss: 0.4431 - val_dice_coefficient: 0.5958
#
# Epoch 00038: val_dice_coefficient did not improve from 0.61184
# Epoch 39/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4149 - dice_coefficient: 0.6162 - val_loss: 0.4211 - val_dice_coefficient: 0.6158
#
# Epoch 00039: val_dice_coefficient improved from 0.61184 to 0.61581, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 40/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4004 - dice_coefficient: 0.6294 - val_loss: 0.4687 - val_dice_coefficient: 0.5735
#
# Epoch 00040: val_dice_coefficient did not improve from 0.61581
# Epoch 41/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4095 - dice_coefficient: 0.6210 - val_loss: 0.4150 - val_dice_coefficient: 0.6204
#
# Epoch 00041: val_dice_coefficient improved from 0.61581 to 0.62038, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 42/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4018 - dice_coefficient: 0.6279 - val_loss: 0.4565 - val_dice_coefficient: 0.5834
#
# Epoch 00042: val_dice_coefficient did not improve from 0.62038
# Epoch 43/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4086 - dice_coefficient: 0.6211 - val_loss: 0.4309 - val_dice_coefficient: 0.6080
#
# Epoch 00043: val_dice_coefficient did not improve from 0.62038
# Epoch 44/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4006 - dice_coefficient: 0.6302 - val_loss: 0.4955 - val_dice_coefficient: 0.5492
#
# Epoch 00044: val_dice_coefficient did not improve from 0.62038
# Epoch 45/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4131 - dice_coefficient: 0.6172 - val_loss: 0.4237 - val_dice_coefficient: 0.6150
#
# Epoch 00045: val_dice_coefficient did not improve from 0.62038
# Epoch 46/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4042 - dice_coefficient: 0.6261 - val_loss: 0.4154 - val_dice_coefficient: 0.6203
#
# Epoch 00046: val_dice_coefficient did not improve from 0.62038
# Epoch 47/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.4004 - dice_coefficient: 0.6287 - val_loss: 0.4130 - val_dice_coefficient: 0.6219
#
# Epoch 00047: val_dice_coefficient improved from 0.62038 to 0.62185, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 48/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.4012 - dice_coefficient: 0.6286 - val_loss: 0.4062 - val_dice_coefficient: 0.6300
#
# Epoch 00048: val_dice_coefficient improved from 0.62185 to 0.63002, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 49/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3970 - dice_coefficient: 0.6329 - val_loss: 0.4204 - val_dice_coefficient: 0.6173
#
# Epoch 00049: val_dice_coefficient did not improve from 0.63002
# Epoch 50/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3973 - dice_coefficient: 0.6319 - val_loss: 0.4084 - val_dice_coefficient: 0.6285
#
# Epoch 00050: val_dice_coefficient did not improve from 0.63002
# Epoch 51/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3984 - dice_coefficient: 0.6317 - val_loss: 0.4224 - val_dice_coefficient: 0.6159
#
# Epoch 00051: val_dice_coefficient did not improve from 0.63002
# Epoch 52/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3902 - dice_coefficient: 0.6398 - val_loss: 0.4170 - val_dice_coefficient: 0.6206
#
# Epoch 00052: val_dice_coefficient did not improve from 0.63002
# Epoch 53/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3923 - dice_coefficient: 0.6371 - val_loss: 0.4160 - val_dice_coefficient: 0.6219
#
# Epoch 00053: val_dice_coefficient did not improve from 0.63002
# Epoch 54/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3876 - dice_coefficient: 0.6417 - val_loss: 0.4396 - val_dice_coefficient: 0.5986
#
# Epoch 00054: val_dice_coefficient did not improve from 0.63002
# Epoch 55/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.3925 - dice_coefficient: 0.6370 - val_loss: 0.4228 - val_dice_coefficient: 0.6141
#
# Epoch 00055: val_dice_coefficient did not improve from 0.63002
# Epoch 56/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.3884 - dice_coefficient: 0.6414 - val_loss: 0.4249 - val_dice_coefficient: 0.6168
#
# Epoch 00056: val_dice_coefficient did not improve from 0.63002
# Epoch 57/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.3864 - dice_coefficient: 0.6421 - val_loss: 0.4406 - val_dice_coefficient: 0.5991
#
# Epoch 00057: val_dice_coefficient did not improve from 0.63002
# Epoch 58/60
# 333/333 [==============================] - 387s 1s/step - loss: 0.3930 - dice_coefficient: 0.6362 - val_loss: 0.4053 - val_dice_coefficient: 0.6312
#
# Epoch 00058: val_dice_coefficient improved from 0.63002 to 0.63119, saving model to /content/drive/MyDrive/cs2/unet.h5
# Epoch 59/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3910 - dice_coefficient: 0.6376 - val_loss: 0.4615 - val_dice_coefficient: 0.5806
#
# Epoch 00059: val_dice_coefficient did not improve from 0.63119
# Epoch 60/60
# 333/333 [==============================] - 386s 1s/step - loss: 0.3865 - dice_coefficient: 0.6420 - val_loss: 0.4295 - val_dice_coefficient: 0.6102
#
# Epoch 00060: val_dice_coefficient did not improve from 0.63119

# %%
# Visualizing history for dice_coefficient
plt.figure(figsize=(12, 8))
plt.plot(history.history['dice_coefficient'])
plt.plot(history.history['val_dice_coefficient'])
plt.title('model dice_coefficient')
plt.ylabel('dice_coefficient')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()
# Visualizing history for loss
plt.figure(figsize=(12, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('bce_dice_loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')
plt.show()

# %%
# saving history data for first 60 epochs in csv file
history1 = pd.DataFrame(history.history)
history1.to_csv(path + "data/history1-unet.csv", index=True)
# saving model(weights upto 60 epochs)
model.save(path+'unet-60epochs.h5')

# %% [markdown]
# ### 5.6 Visualizing Model Predictions

# %%
# evaluating model(best weights) with the validation batch
model.load_weights(path + 'unet.h5')
loss, dc= model.evaluate(validtn_batches,verbose=1)
print('loss:',loss, 'dice_coefficient:',dc)
# Out:
# 58/58 [==============================] - 38s 649ms/step - loss: 0.4053 - dice_coefficient: 0.6312
# loss: 0.40530264377593994 dice_coefficient: 0.6311885118484497

# %%
#defining function to display GroundTruth & Predicted mask images for a given imageId
def visualize_model_prediction(img_id):
    fig, axs = plt.subplots(4, 3, figsize=(16,8))
    img_obj = cv2.imread(path+'data/train_images/'+ img_id)
    masks_actual = full_data[full_data['ImageId'] == img_id]
    x = np.empty((1,256,1600,3),dtype=np.float32) # image place-holders
    x[0,] = Image.open(path+'data/train_images/' + img_id)
    masks_predicted = model.predict(x)
    for i in range(4):
        axs[i,0].imshow(img_obj)
        axs[i,0].set_title(img_id)
        axs[i,1].imshow(rle2mask(masks_actual['rle_'+str(i+1)].iloc[0]))
        axs[i,1].set_title("Actual mask for Class '{}'".format(i+1) )
        axs[i,2].imshow(masks_predicted[0,:,:,i])
        axs[i,2].set_title("Predicted mask for Class '{}'".format(i+1))
    plt.show()

# %%
visualize_model_prediction('0002cc93b.jpg')

# %%
visualize_model_prediction('4d38c353e.jpg')

# %% [markdown]
# ### 5.7 Preparing Data for submission

# %%
class PredictDataGenerator(tf.keras.utils.Sequence):
    def __init__(self,dataframe, list_idcs, batch_size=32, ):
        self.batch_size = batch_size
        self.df = dataframe
        self.list_idcs = list_idcs
        self.indices = self.df.index.tolist()
        self.rem = len(self.list_idcs) % (self.batch_size)
        self.on_epoch_end()

    def __len__(self):
         return len(self.list_idcs) // (self.batch_size)
#         if (self.rem) == 0:
#             return len(self.list_idcs) // (self.batch_size)
#         else:
#             return (len(self.list_idcs) // (self.batch_size) )+1

    def __getitem__(self, index):
        index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         if ((index + 1) * self.batch_size) < len(self.list_idcs):
#             index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
#         else:
#             index = self.indices[index * self.batch_size: (index * self.batch_size)+ self.rem]
        batch = [self.list_idcs[k] for k in index]
        
        X = self.__get_data(batch)
         
        return X
    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))

    def __get_data(self, batch):
        X = np.empty((self.batch_size,256,1600,3),dtype=np.float32) # image place-holders
              
        for i, id in enumerate(batch):
            img = Image.open(path + 'data/test_images/' + str(self.df['ImageId'].loc[id]))
            X[i,] = img#input image

        return X

# %%
test_img_IDs = list(os.listdir(path + 'data/test_images/'))
test_imgsIds_df = pd.DataFrame({'ImageId': test_img_IDs})
print(len(test_imgsIds_df))
test_imgsIds_df.head()
# Out:
# 5506
#          ImageId
# 0  ede66fecf.jpg
# 1  ec6434bac.jpg
# 2  f0bd6beec.jpg
# 3  edfba47f3.jpg
# 4  f27c44348.jpg

# %%
SubmissionDf = pd.DataFrame(columns = ['ImageId','EncodedPixels','ClassId'])

# %%
for i in range(0,len(test_imgsIds_df),320):
    batch_idcs =  list(range(i, min(test_imgsIds_df.shape[0], i + 320)))#.iloc[batch_idcs]
    if len(batch_idcs)== 320:        
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs)
    else:
        test_subbatch = PredictDataGenerator(dataframe = test_imgsIds_df,
                                             list_idcs = batch_idcs,
                                             batch_size= len(batch_idcs))
    #print(len(test_subbatch))
    subbatch_pred_masks = model.predict(test_subbatch)
    #print(len(subbatch_pred_masks))
    #break
    for j, idx in tqdm(enumerate(batch_idcs)):
        filename = test_imgsIds_df['ImageId'].iloc[idx]
        rle1 = mask2rle(subbatch_pred_masks[j,:,:,0].round().astype(int))
        rle2 = mask2rle(subbatch_pred_masks[j,:,:,1].round().astype(int))
        rle3 = mask2rle(subbatch_pred_masks[j,:,:,2].round().astype(int))
        rle4 = mask2rle(subbatch_pred_masks[j,:,:,3].round().astype(int))
        df = pd.DataFrame({'ImageId':[filename]*4,
                      'EncodedPixels': [rle1,rle2,rle3,rle4],
                      'ClassId':['1', '2', '3', '4']})
        SubmissionDf = SubmissionDf.append(df,ignore_index=True)
# Out:
# 320it [00:03, 83.77it/s]
# 320it [00:03, 83.25it/s]
# 320it [00:03, 81.83it/s]
# 320it [00:03, 83.58it/s]
# 320it [00:04, 78.22it/s]
# 320it [00:04, 71.69it/s]
# 320it [00:04, 74.47it/s]
# 320it [00:04, 77.51it/s]
# 320it [00:04, 74.26it/s]
# 320it [00:04, 72.66it/s]
# 320it [00:04, 71.14it/s]
# 320it [00:04, 70.75it/s]
# 320it [00:04, 71.68it/s]
# 320it [00:04, 72.28it/s]
# 320it [00:04, 75.11it/s]
# 320it [00:05, 58.94it/s]
# 320it [00:05, 57.15it/s]
# 66it [00:01, 56.58it/s]

# %%
SubmissionDf.sort_values(by=['ImageId', 'ClassId'], inplace=True)
SubmissionDf['ImageId_ClassId'] = SubmissionDf['ImageId'] + '_' + SubmissionDf['ClassId']
print(SubmissionDf.shape)
SubmissionDf.head(10)
# Out:
# (22024, 4)
#              ImageId  ...  ImageId_ClassId
# 20256  0000f269f.jpg  ...  0000f269f.jpg_1
# 20257  0000f269f.jpg  ...  0000f269f.jpg_2
# 20258  0000f269f.jpg  ...  0000f269f.jpg_3
# 20259  0000f269f.jpg  ...  0000f269f.jpg_4
# 20244  000ccc2ac.jpg  ...  000ccc2ac.jpg_1
# 20245  000ccc2ac.jpg  ...  000ccc2ac.jpg_2
# 20246  000ccc2ac.jpg  ...  000ccc2ac.jpg_3
# 20247  000ccc2ac.jpg  ...  000ccc2ac.jpg_4
# 20252  002451917.jpg  ...  002451917.jpg_1
# 20253  002451917.jpg  ...  002451917.jpg_2
#
# [10 rows x 4 columns]

# %%
SubmissionDf.to_csv(path+'submission-unet.csv', index=False)

# %% [markdown]
# ### 5.8 Kaggle Submission Score

# %%
#Kaggle Score
from IPython.display import Image
Image(filename='unet.JPG')
